# %%
print('Hello world')
# Out:
# Hello world

# %%
name = 'Ed'
print('Hello', name)
# Out:
# Hello Ed

# %%
# Shift + Enter - Run the code
print(name)
# Out:
# Ed

# %% [markdown]
# we do data analysis on jupyter
# # Literate Programming
# The idea that programming is first about human beings understanding things, and then later about computers doing it.

# %%
import requests
response = requests.get('https://api.darksky.net/forecast/0ad40e8943cdfa0611435801234ed06f/37.8267,-122.4233')

# %%
print(response)
# Out:
# <Response [200]>

# %%
# HTTP status code

# %%
response
# Out:
# <Response [200]>

# %%
numbers = [1, 2, 3, 4, 5]
numbers[-1]
# Out:
# 5

# %%
for number in numbers:
    number

# %%
for number in numbers:
    print(number)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
data = response.json()

# %%
data.keys()
# Out:
# dict_keys(['latitude', 'longitude', 'timezone', 'currently', 'minutely', 'hourly', 'daily', 'flags', 'offset'])

# %%
data['latitude']
# Out:
# 37.8267

# %%
data['longitude']
# Out:
# -122.4233

# %%
data
# Out:
# {'latitude': 37.8267,
#  'longitude': -122.4233,
#  'timezone': 'America/Los_Angeles',
#  'currently': {'time': 1527698641,
#   'summary': 'Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'nearestStormDistance': 25,
#   'nearestStormBearing': 78,
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 55.44,
#   'apparentTemperature': 55.44,
#   'dewPoint': 47.69,
#   'humidity': 0.75,
#   'pressure': 1010.02,
#   'windSpeed': 9.59,
#   'windGust': 13.85,
#   'windBearing': 243,
#   'cloudCover': 0.61,
#   'uvIndex': 2,
#   'visibility': 7.48,
#   'ozone': 338.39},
#  'minutely': {'summary': 'Mostly cloudy for the hour.',
#   'icon': 'partly-cloudy-day',
#   'data': [{'time': 1527698640, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1527698700, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1527698760, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1527698820, 'precipIntensity': 0, 'precipProbability': 0},
# ...

# %%
response = requests.get('https://api.darksky.net/forecast/0ad40e8943cdfa0611435801234ed06f/40.7128,-74.0060')

# %%
response.keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-188cbbee4291> in <module>()
# ----> 1 response.keys()
#
# AttributeError: 'Response' object has no attribute 'keys'

# %%
response
# Out:
# <Response [200]>

# %%
data = response.json()

# %%
data.keys()
# Out:
# dict_keys(['latitude', 'longitude', 'timezone', 'currently', 'minutely', 'hourly', 'daily', 'flags', 'offset'])

# %%
data['currently']
# Out:
# {'time': 1527699065,
#  'summary': 'Overcast',
#  'icon': 'cloudy',
#  'nearestStormDistance': 16,
#  'nearestStormBearing': 0,
#  'precipIntensity': 0,
#  'precipProbability': 0,
#  'temperature': 69.59,
#  'apparentTemperature': 70.1,
#  'dewPoint': 63.85,
#  'humidity': 0.82,
#  'pressure': 1020.96,
#  'windSpeed': 7.62,
#  'windGust': 8.46,
#  'windBearing': 109,
#  'cloudCover': 0.95,
#  'uvIndex': 6,
#  'visibility': 8.84,
#  'ozone': 318.75}
