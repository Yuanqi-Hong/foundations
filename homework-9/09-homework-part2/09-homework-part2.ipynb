# %% [markdown]
# # Using Scraping

# %% [markdown]
# Scrape the front page of some always-updating website (some websites won't work with BeautifulSoup).
#
# Send yourself an email with as much information as possible from the site, such as:
#
#  - The title of the thing (the sale, the article, whatever)
#  - A URL for it
#  - Upvotes/thumbs ups/subreddits/prices/links to images/etc
#
# Save this as a CSV, and send it as an attachment to your email address every 6 hours. The email headline should say something like "**Here is your 6PM briefing.**" The CSV file should be timestamped with the current date and time, e.g. `briefing-2018-06-18-3PM.csv`
#
# **BONUS**: Have the content actually be the **body** of the email, not just an attachment. I don't mean like a CSV or whatever, I mean it should actually look like nice lists and stuff, a real email.

# %%
from bs4 import BeautifulSoup
import requests
import datetime
import re
import pandas as pd

# %%
# For this assignment, I'm scraping China-related news from Google News.
response = requests.get("https://news.google.com/search?q=China&hl=en-US&gl=US&ceid=US%3Aen").content
soup = BeautifulSoup(response, "html.parser")

# %%
# Before we put the data into a df, we use print() to make sure our program works

# The first two blocks are featured article groups (with 'View more' buttons).
# They need to be dealt with separately.
# And since we don't know if the number of featured blocks is gonna change,
# we have to find the uniqueness of these blocks.
# I'm only taking the first article of each group for simplicity.

# It could be observed that the featured blocks have an attr 'jscontroller', whose value is d0DtYd
featured = soup.find(class_='lBwEZb BL5WZb xP6mwf').findAll('div',attrs={'jscontroller':'d0DtYd'})
for feature in featured:
    feature_article = feature.find('article').find(class_='ZulkBc qNiaOd')
    feature_title = feature_article.span.text
    feature_url = 'https://news.google.com'+feature_article.a['href'][1:]
    feature_first_lines = feature_article.find(class_='HO8did Baotjf').text
    feature_source = feature.find(class_='QmrVtf kybdz').find('div',attrs={'class':'PNwZO zhsNkd'}).text
    feature_rawtime = feature.find('time')['datetime'].split(': ')[1]
    feature_time = datetime.datetime.fromtimestamp(int(feature_rawtime)).strftime('%Y-%m-%d %H:%M:%S')
    print(feature_title)
    print(feature_url)
    print(feature_first_lines)
    print(feature_source)
    print(feature_time)

# The other "normal" articles have an attr 'jsmodel', whose value is 'zT6vwb'
articles = soup.find(class_='lBwEZb BL5WZb xP6mwf').findAll('div',attrs={'jsmodel':'zT6vwb'})

for article in articles:
    article_title = article.find('span').text
    article_url = 'https://news.google.com'+article.find('a',attrs={'class':'ipQwMb Q7tWef'})['href'][1:]
    article_first_lines = article.find('p').text
    article_source = article.find(class_='KbnJ8').text
    article_rawtime = re.findall(r'[\d]+', article.find('time')['datetime'].split(': ')[1])[0]
    article_time = datetime.datetime.fromtimestamp(int(article_rawtime)).strftime('%Y-%m-%d %H:%M:%S')
    print(article_title)
    print(article_url)
    print(article_first_lines)
    print(article_source)
    print(article_time)
# Out:
# Trump's Trade War Spooks Markets as White House Waits for China to Blink
# https://news.google.com/articles/CAIiEP_Fh8Itu1ElBc1lC3IA7poqFwgEKg8IACoHCAowjuuKAzCWrzww9oAY
# The administration, threatening tariffs on as much as $450 billion worth of goods, believes Beijing has more to lose. Companies, investors and markets are ...
# The New York Times
# 2018-06-19 12:15:02
# North Korea’s Kim makes another trip to China. That complicates things for Trump.
# https://news.google.com/articles/CAIiEHraYy5Ba-EgBuspvANtpzsqGAgEKg8IACoHCAowjtSUCjC30XQwn6G5AQ
# BEIJING — North Korean leader Kim Jong Un is in China. Again. Kim arrived Tuesday for his third visit to China in the span of three months, meeting with ...
# The Washington Post
# 2018-06-19 20:10:42
# There's no better example of Trump's trade fight with China than Lockheed Martin's crown jewel
# https://news.google.com/articles/CAIiED_SAADQC-_WefGjAs6jJH4qGQgEKhAIACoHCAow2Nb3CjDivdcCMKuvhQY
# The Chinese J-31 fighter jet is believed to be a knockoff of Lockheed Martin's F-35.
# CNBC
# 2018-06-19 16:25:00
# An investor monitors stock prices at a securities company in Shanghai on May 30, 2018. - Asian equities and the euro sank as turmoil in Italy sparked a frantic dash for safety, while investors have also been spooked by fresh worries about the China-US trade row. (Photo by Johannes EISELE / AFP) (Photo credit should read JOHANNES EISELE/AFP/Getty Images) Photographer: JOHANNES EISELE/AFP
# https://news.google.com/articles/CAIiENJ_q3-lfCqsBPxkIW1dCW4qGQgEKhAIACoHCAow4uzwCjCF3bsCMIrOrwM
# In a stock market where investors are used to being disappointed, Tuesday's plunge still shocked. China's benchmark equity gauge sank almost 5 percent at one ...
# Bloomberg
# 2018-06-19 06:34:21
# President Donald Trump
# https://news.google.com/articles/CAIiEG_t_R7iie14nJk2RORpKhkqGAgEKg8IACoHCAowjujJATDXzBUwmJS0AQ
# If a trade war were to escalate, the fragile balance in the Chinese economy could be tipped, and we may very well experience a second Asian crisis, says Ivan ...
# MarketWatch
# 2018-06-19 14:59:00
# China’s yuan hits fresh 5-month low as trade fight with U.S. intensifies
# https://news.google.com/articles/CAIiEPpLqgRyLbLBPZ_kde6Fk9UqGAgEKg8IACoHCAowjujJATDXzBUwqJS0AQ
# Blame trade-war worries, not intervention by China's central bank, for recent weakness in the yuan, analysts said at the start of this week.
# MarketWatch
# 2018-06-19 09:05:00
# Big investors — including Buffett, Tudor Jones — aren’t worried about a trade war with China
# https://news.google.com/articles/CAIiECfSI3Lr-w13Eq8s4Sd1Y8IqGQgEKhAIACoHCAow2Nb3CjDivdcCMJ_d7gU
# Several experienced market veterans predict the U.S. and China will eventually reach a satisfactory trade deal.
# CNBC
# 2018-06-19 13:33:00
# A Chinese worker polishes steel at an offshore oil engineering platform in China’s Shandong province.
# https://news.google.com/articles/CAIiEGAh5T8tk6Ib5CuZHlWvEogqGAgEKg8IACoHCAowjujJATDXzBUwmJS0AQ
# European stocks stumble to a near three-week low Tuesday, after U.S. President Donald Trump indicated his administration is looking to hit China with further ...
# MarketWatch
# 2018-06-19 13:12:00
# Dow tumbles about 300 points, wipes out gains for year, as Trump directs more tariffs at China
# https://news.google.com/articles/CAIiEJePBXI5IVoMLTizcz1GK4YqGQgEKhAIACoHCAow2Nb3CjDivdcCMJ_d7gU
# Stocks fell sharply on Tuesday after President Donald Trump's latest threat to China increased fears of an impending trade war between the world's largest ...
# CNBC
# 2018-06-19 05:22:00
# China's central bank delivers surprise stimulus as trade spat with US worsens
# https://news.google._YW1wX2pzX3Y9MC4xI3dlYnZpZXc9MQ
# China's central bank on Tuesday lent 200 billion yuan ($31 billion) to financial institutions via its medium-term lending facility (MLF), highlighting concerns over ...
# CNBC
# 2018-06-18 23:55:00
# China: America's new Taiwan embassy infuriates Beijing
# https://news.google.com/articles/CBMimAFodHRwczovL3d3dy5uZXdzLmNvbS5hdS9maW5hbmNlL2Vjb25vbXkvd29ybGQtZWNvbm9teS93aHktdGhpcy0yNTVtLWJ1aWxkaW5nLXJlbm92YXRpb24td2lsbC1pbmZ1cmlhdGUtY2hpbmEvbmV3cy1zdG9yeS8zOGJjMTM3ZjA3MWExZDQ4NDBiZjZjNjAzNWU2MWU0ZdIBAA
# THIS building doesn't look like anything special — but with $255 million sunk into its renovation, it is threatening to cause an international incident.
# NEWS.com.au
# 2018-06-19 09:18:31
# China regulator Safe revealed as controller of 5% stake in EDP
# https://news.google.com/articles/CAIiEKpGhhPp2-0YnhEBT_wYwwQqFwgEKg8IACoHCAow-4fWBzD4z0gw0tp6
# China's State Administration of Foreign Exchange is the entity behind a mysterious 5 per cent stake in EDP, the Portuguese utility facing a €9bn takeover bid ...
# Financial Times
# 2018-06-19 14:10:15
# Can China kick its animal antibiotic habit?
# https://news.google._YW1wX2pzX3Y9MC4xI3dlYnZpZXc9MQ
# It could be a struggle, but the world's largest consumer of antibiotics is trying to convince its farmers to change their ways.
# The Guardian
# 2018-06-19 10:07:00
# Sundar Pichai, Google's C.E.O., speaking at the China Development Forum in Beijing earlier this year.
# https://news.google.com/articles/CAIiEFjk1NfqhxKOXiAaHF4Zo1gqFwgEKg8IACoHCAowjuuKAzCWrzww9oAY
# The company's $550 million investment is another sign of how American tech giants still want to do business in China, despite the many hurdles.
# The New York Times
# 2018-06-18 15:33:31
# China is creating a huge carbon market—but not a particularly aggressive one
# https://news.google.com/articles/CAIiECSRYH1c2JcPzKId1a_Q6LMqFggEKg0IACoGCAowof8GMMBfMKbW8wU
# China, the world's largest communist country and its biggest climate polluter, has turned to a decidedly free-market approach to combating carbon emissions.
# MIT Technology Review
# 2018-06-18 08:00:00
# Lloyd Blankfein Photographer: Scott Eells
# https://news.google.com/articles/CAIiEL6VFl8xlJa8neJa9jbTjfYqGQgEKhAIACoHCAow4uzwCjCF3bsCMK3JrwM
# The Trump administration's tariff threats against China make sense as a bargaining strategy and probably won't bring about a devastating trade war, Goldman ...
# Bloomberg
# 2018-06-19 13:00:52
# North Korean leader Kim Jong Un is in China on a two-day visit: Chinese state media
# https://news.google.
# North Korean leader Kim Jong Un arrived in Beijing on Tuesday, where he will likely brief Chinese President Xi Jinping on his summit with U.S. President ...
# CNBC
# 2018-06-18 22:26:00
# China Has a Nuclear Option in the Trade War
# https://news.google._YW1wX2pzX3Y9MC4xI3dlYnZpZXc9MQ
# It could trigger mutually assured economic destruction, if cooler heads don't prevail.
# Bloomberg
# 2018-06-19 16:33:00
# Vietnamese Catholics march to protest against the Special Economic Zone's laws after a Sunday mass at a village in Ha Tinh province, Vietnam on June 17, 2018. Some citizens are suspicious that the Vietnamese communist government is giving in to Chinese requests for the economic zones. (Reuters)
# https://news.google.com/articles/CAIiECFw3ir4VTt1E509nOPkrl8qFQgEKg0IACoGCAow3PcFMNFXMMmzAg
# Popular opinion has concluded that China will be the main beneficiary of pending economic policy in Vietnam, triggering two weeks of protests. Protestors fear ...
# The Christian Science Monitor
# 2018-06-19 11:04:24
# play_arrow
# https://news.google.com/articles/CAIiEJ0_8nyyotOPxePff3xZBasqGQgEKhAIACoHCAowocv1CjCSptoCMPrTpgU
# US President Donald Trump's mooted Space Force, which he suggested will be a "separate but equal" branch of the military, is vital to maintaining a tactical ...
# CNN
# 2018-06-19 20:41:23
# Google is investing $550 million in the Chinese online retailer JD.com. In return, the Chinese company will work with Google on e-commerce projects elsewhere in the world.
# https://news.google.com/articles/CAIiEKHvW4GlclMMM4LnO1va9FgqFwgEKg8IACoHCAowjuuKAzCWrzww5oEY
# Google is investing $550 million in the Chinese online retailer JD.com. In return, the Chinese company will work with Google on e-commerce projects elsewhere ...
# The New York Times
# 2018-06-18 06:02:28
# -/Agence France-Presse/Getty Images
# https://news.google.com/articles/CAIiEEsYRLlMOR67IBeZVpSokKQqGAgEKg8IACoHCAow1tzJATDnyxUw-aS0AQ
# HONG KONG—Chinese smartphone maker Xiaomi Corp. postponed a widely anticipated share sale in mainland China, saying it would proceed first with an ...
# The Wall Street Journal
# 2018-06-19 01:57:00
# Wall Street Breakfast: China Labels It A 'Trade War'
# https://news.google.
# Listen on the go! A daily podcast of Wall Street Breakfast will be available by 8:00 a.m. on iTunes, Stitcher and SoundCloud (click the highlighted links). Chin.
# Seeking Alpha
# 2018-06-19 06:57:00
# Checking China's pollution, by satellite
# https://news.google.com/articles/CBMiQ2h0dHA6Ly9uZXdzLm1pdC5lZHUvMjAxOC9jaGVja2luZy1jaGluYS1wb2xsdXRpb24tYnktc2F0ZWxsaXRlLTA2MTjSAQA
# An MIT-led study used satellite data to find reductions in sulfur emissions from power plants in China.
# MIT News
# 2018-06-18 15:16:14
# US president Donald Trump shakes hand with China’s president Xi Jinping in Beijing in November 2017. Trump’s tariff threats have not been well received in China.
# https://news.google.com/articles/CAIiEPd18B-rf7k_Z_ODBqfbj0AqFggEKg4IACoGCAowl6p7MN-zCTDlkko
# Chinese state media has attacked the White House for escalating the prospect of a trade war, calling the administration of president Donald Trump “selfish” and ...
# The Guardian
# 2018-06-18 00:59:31
# Reduction in sulfur emissions from power plants in China: Checking China's pollution by satellite
# https://news.google.com/articles/CBMiPmh0dHBzOi8vd3d3LnNjaWVuY2VkYWlseS5jb20vcmVsZWFzZXMvMjAxOC8wNi8xODA2MTgyMjI2MjAuaHRt0gEA
# Air pollution has smothered China's cities in recent decades. In response, the Chinese government has implemented measures to clean up its skies. But are ...
# Science Daily
# 2018-06-18 23:54:37
# Mike Pompeo, U.S. secretary of state, speaks during an Economic Club of Detroit meeting in Detroit, Michigan, U.S., on Monday, June 18, 2018. U.S. is dealing with "an unprecedented level of larceny" from China, which is the "main perpetrator" of foreign practices that harm the U.S. said Pompeo.
# https://news.google.com/articles/CAIiECazsHYq8KYvKYtNpaYCQ8MqGQgEKhAIACoHCAow4uzwCjCF3bsCMK3JrwM
# Secretary of State Mike Pompeo amplified President Donald Trump's tough line in a brewing trade war with China in a speech on Monday, saying U.S. action ...
# Bloomberg
# 2018-06-18 15:16:14
# Here’s why a trade-war selloff won’t spark intervention in China’s yuan
# https://news.google.com/articles/CAIiEOzZ2bht6vcP8hDxgLl_nIwqGAgEKg8IACoHCAowjujJATDXzBUwqJS0AQ
# The selloff in the yuan intensified on Tuesday, spilling into other assets, but isn't yet reason for panic, analysts say.
# MarketWatch
# 2018-06-19 13:58:00
# Asian shares decline after escalation in US-China trade tensions as oil extends losses
# https://news.google.com/articles/CAIiEH990LgeQ8FFa0Bl7XLNq4cqGQgEKhAIACoHCAow2Nb3CjDivdcCMJ_d7gU
# Asian markets fell on Monday after tariffs imposed by the U.S. on Chinese goods were met with swift retaliation from Beijing.
# CNBC
# 2018-06-17 19:35:00
# CEO of a China's JD.com says a trade war would hurt 'a lot of American brands'
# https://news.google.com/articles/CAIiEC7RgjvRBIclryf1HMLKaTcqGQgEKhAIACoHCAow2Nb3CjDivdcCMMPf7gU
# JD.com Founder and CEO Richard Liu told CNBC that American companies could potentially lose opportunities to sell to a large consumer base in China.
# CNBC
# 2018-06-17 22:38:00
# The most distinguishing feature of Chinese thinking and, by extension, innovation is its systems approach, writes Ang [Reuters]
# https://news.google.com/articles/CAIiEL-6zyZGk8Nq0unk-ueFVNwqFAgEKgwIACoFCAowhgIwkDgwob0I
# China's innovation path does not follow the Western one and it doesn't have to.
# Al Jazeera English
# 2018-06-17 08:08:37
# Press Pool
# https://news.google.com/articles/CAIiEM453jsAPMGdErx59XDyNS0qFwgEKg8IACoHCAow1tzJATDnyxUw54IY
# Japanese Prime Minister Shinzo Abe, after years of skirmishing with China over territory and security, is now promoting a rapprochement with Beijing that ...
# The Wall Street Journal
# 2018-06-18 21:00:00
# China’s social credit system spreads to more daily transactions
# https://news.google._YW1wX2pzX3Y9MC4xI3dlYnZpZXc9MQ
# In May, enforcement of China's social credit system spread to the travel industry, restricting millions of Chinese citizens with low social credit scores from ...
# Brookings Institution
# 2018-06-18 07:03:10
# China's Subsidy Cut Puts Grid Parity In Reach
# https://news.google.
# Two weeks ago, the National Development and Reform Commission and the National Energy Administration announced to focus on quality over scale by cutting ...
# Seeking Alpha
# 2018-06-19 09:20:00
# Battery Fever Grips China’s Stock MarketBattery Fever Grips China's Stock Market | Greentech Media
# https://news.google.com/articles/CAIiEFLWEszmYjDkTJq1c8_zJdMqGQgEKhAIACoHCAow3rv_CjC88fgCMIn66QU
# After a wildly successful IPO, lithium-ion giant CATL is looking to build plants in China and Germany.
# Greentech Media News
# 2018-06-18 06:00:39
# Shares of China's ZTE sink 23% after US Senate targets company in new bill
# https://news.google.com/articles/CAIiEFR_XQuPVZ_mhN8iDVzSkE0qGQgEKhAIACoHCAow2Nb3CjDivdcCMMPf7gU
# Shares of ZTE sank after the U.S. Senate passed a defense bill that had implications for an agreement struck with the Chinese telecommunications equipment ...
# CNBC
# 2018-06-18 22:58:00
# Why the Summit supercomputer beating China's TaihuLight matters
# https://news.google.com/articles/CBMiXmh0dHA6Ly93d3cud2lyZWQuY28udWsvYXJ0aWNsZS9pYm0tc3VtbWl0LXN1cGVyY29tcHV0ZXItY2hpbmEtdGFpaHVsaWdodC1mYXN0ZXN0LXN1cGVyY29tcHV0ZXLSAQA
# Multi-million dollar projects to eke out an advantage in processing power aren't really about science, they're an exercise in soft power.
# Wired.co.uk
# 2018-06-19 02:05:05
# North Korean leader Kim Jong Un visiting China: Chinese state media
# https://news.google.com/articles/CAIiELIgHTIEAUZ9fBob17Zzd4wqFQgEKg0IACoGCAowt6AMMLAmMJSCDg
# BEIJING (Reuters) - North Korea leader Kim Jong Un is in China on a two-day visit, Chinese state television said on Tuesday, his third visit to the North's major ...
# Reuters
# 2018-06-18 22:16:07
# Trade tariffs: Chinese media in Trump 'fools build walls' jibe
# https://news.google.com/articles/CBMiMmh0dHBzOi8vd3d3LmJiYy5jb20vbmV3cy93b3JsZC1hc2lhLWNoaW5hLTQ0NTA1NDQ40gFwaHR0cHM6Ly93d3ctYmJjLWNvbS5jZG4uYW1wcHJvamVjdC5vcmcvdi9zL3d3dy5iYmMuY29tL25ld3MvYW1wL3dvcmxkLWFzaWEtY2hpbmEtNDQ1MDU0NDg_YW1wX2pzX3Y9MC4xI3dlYnZpZXc9MQ
# Chinese media have mocked US President Donald Trump over plans to impose 25% tariffs on $50bn worth of Chinese goods, saying "wise men build bridges ...
# BBC News
# 2018-06-16 05:21:09
# China's tariffs on U.S. oil would disrupt $1 billion monthly business
# https://news.google.com/articles/CAIiENF1Ipeor57dF4HGQk_NwPUqFQgEKg0IACoGCAowt6AMMLAmMJSCDg
# China's threat to impose duties on U.S. oil imports will hit a business that has soared in the last two years, and which is now worth almost $1 billion per month.
# Reuters
# 2018-06-18 02:34:29
# China and India’s border dispute is a slow-moving environmental disaster
# https://news.google.
# Chinese and Indian competition on their shared Himalayan border is more likely to create a slow-moving environmental catastrophe than a quick military or ...
# The Conversation AU
# 2018-06-17 14:53:00
# Photo Illustration by Lyne Lucien/The Daily Beast
# https://news.google.com/articles/CAIiEPV7FoasBQHkHiD1or7KRJwqFQgEKg0IACoGCAow7s8BMNBIMPGMAg
# In its ongoing campaign to extend its reach beyond its borders, the Chinese government has found a new form of leverage: American citizens in China. Last year ...
# The Daily Beast
# 2018-06-18 04:48:36
# India, China ties cannot take strain of another Doklam, says Chinese envoy
# https://news.google.com/articles/CAIiEMowfU3wN6DSND-nrMUVd58qFwgEKg8IACoHCAow34KMAjCz9Swwr7NB
# Bilateral ties between India and China can't take the strain of another Doklam episode, Chinese envoy to India Luo Zhaohui said today, emphasising on the ...
# The Economic Times
# 2018-06-18 15:55:29
# China is the biggest market for Alaska seafood exports. The tariff war is raising concerns.
# https://news.google....
# Alaska seafood is among the industries caught in the growing trade battle between the United States and China, and it's not clear yet exactly what the outcome ...
# Anchorage Daily News
# 2018-06-18 21:31:35
# Man behind China’s new aircraft carrier held in graft investigation
# https://news.google.com/articles/CAIiEGZKkH6vCLZfovOG1cwdWy4qGQgEKhAIACoHCAowief2CjCJ2dUCMNvwrAU
# The deputy head of the shipbuilder developing China's first home-grown aircraft carrier has been detained on suspicion of disciplinary violations, the usual ...
# South China Morning Post
# 2018-06-17 03:26:41
# Workers at the end of their shift outside a furnace for molten iron in the production area of the Zhong Tian (Zenith) Steel Group Corporation in Changzhou, Jiangsu.
# https://news.google.com/articles/CAIiECYQEeWRcJrkioYQqQ0dnjcqGAgEKg8IACoHCAowjujJATDXzBUw2JS0AQ
# China was supposed to be curtailing steel production as it pivoted to a *service*-sector, clean economy, but that hasn't happened. Here's a look at the research ...
# MarketWatch
# 2018-06-16 12:01:00
# Teng Biao, a Chinese human rights lawyer who moved to the United States after being harassed by the Chinese authorities, speaking at a hearing on Capitol Hill in Washington in 2015.
# https://news.google.com/articles/CAIiEAkbPKBfx10nFOCL5AFL3MgqFwgEKg8IACoHCAowjuuKAzCWrzww5oEY
# From his suburban home in New Jersey, Teng Biao has watched in frustration as what he sees as the apologies to China from Western companies have come ...
# The New York Times
# 2018-06-15 12:29:12
# Overuse of agricultural chemicals on China's small farms harms health and environment
# https://news.google.com/articles/CBMiPmh0dHBzOi8vd3d3LnNjaWVuY2VkYWlseS5jb20vcmVsZWFzZXMvMjAxOC8wNi8xODA2MTgyMjI1MTEuaHRt0gEA
# The size of farms in China is a key contributor to the overuse of agricultural chemicals, and as a result they may be too small to be environmentally sustainable, ...
# Science Daily
# 2018-06-19 00:01:44
# Don’t Fear China’s Industrial Juggernaut
# https://news.google.
# Washington is working up a sweat over China's industrial policies. There are fears Beijing will build technology companies and advanced manufacturers ...
# Bloomberg
# 2018-06-17 03:00:00
# UBS Group CEO: I'm really worried about Trump-China trade war threats getting 'out of control'
# https://news.google.com/articles/CAIiEGxtfBI5Z380cDHnGLuqfIgqGQgEKhAIACoHCAow2Nb3CjDivdcCMJ_d7gU
# Wealthy investors are holding more cash just in case of a full-blown trade war, says UBS' Sergio Ermotti.
# CNBC
# 2018-06-18 08:56:00
# Rand under 'massive pressure' as Trump drops next tariff bomb on China
# https://news.google.com/articles/CBMiY2h0dHBzOi8vd3d3LmZpbjI0LmNvbS9NYXJrZXRzL0N1cnJlbmNpZXMvcmFuZC11bmRlci1tYXNzaXZlLXByZXNzdXJlLWFzLXRyYWRlLXdhcnMtaGVhdC11cC0yMDE4MDYxOdIBAA
# The rand came under "massive pressure" on Tuesday morning, having weakened from R13.63 to R13.90, following news that US President Donald Trump is ...
# Fin24
# 2018-06-19 03:46:00
# China adds to nuclear arsenal amid military modernisation drive
# https://news.google.com/articles/CAIiEPSFM0QXiVi57w3SfmEIVnkqGQgEKhAIACoHCAowief2CjCJ2dUCMNvwrAU
# China is pushing ahead with modernising its nuclear weapon delivery systems and has added to its arsenal as it boosts military expenditure, according to a ...
# South China Morning Post
# 2018-06-18 08:02:17
# Beijing subways could get facial recognition and palm scanning tech, Chinese media reports
# https://news.google.com/articles/CAIiEL9fJk2BCncC_dhg712EJ_8qGQgEKhAIACoHCAow2Nb3CjDivdcCMMPf7gU
# Biometric technology on public transport in China could raise fears that commuters are being spied on.
# CNBC
# 2018-06-19 03:24:00
# A factory in Hangzhou, China. An economic slowdown in the country — coupled with the knock-on effects of widening trade disputes and slowing growth in Europe — may augur poorly for the global economy.
# https://news.google.com/articles/CAIiEAkS2ggxnfq10P6yMXXlWkgqFwgEKg8IACoHCAowjuuKAzCWrzwwt4QY
# The country's focus on reducing its debt has left small businesses facing a credit crunch, and the economy appears to be slowing.
# The New York Times
# 2018-06-14 09:11:00
# All eyes on China’s reachout to Mamata Banerjee
# https://news.google....
# KOLKATA: China is readying to roll out the red carpet for West Bengal chief minister Mamata Banerjee, who is all set to visit the country for a week from June 22.
# Economic Times
# 2018-06-18 22:06:00
# Dow posts 5-day losing streak on lingering US-China trade tensions
# https://news.google.com/articles/CAIiENCS9i5M6NB3hoExN1FuUFgqGQgEKhAIACoHCAow2Nb3CjDivdcCMJ_d7gU
# Stocks fell on Monday as a potential trade war between the U.S. and China — the world's largest economies in the world — left Wall Street rattled. The Dow ...
# CNBC
# 2018-06-18 05:45:00
# China is the biggest winner of the Trump-Kim summit
# https://news.google.com/articles/CAIiEDaFlqEV-yM_fO4neWxfsjkqFwgEKg8IACoHCAowlOzSATCaiDUwo9dy
# China got exactly what it wanted from Trump at the North Korea summit.
# Vox.com
# 2018-06-13 13:30:02
# China Box Office: ‘Jurassic World: Fallen Kingdom’ Opening Dominates Weekend
# https://news.google.com/articles/CAIiEMtBqYk_Zbpmu8SEGiNDQUoqFwgEKg8IACoHCAowraj2AjC5-iIw3Itb
# A blockbuster opening by “Jurassic World: Fallen Kingdom” lifted the Chinese box office from one of its lowest weekends of the year to one of its strongest.
# Variety
# 2018-06-17 20:44:17
# China Is Low-Key Taking Over the World: Weekend Edition
# https://news.google.
# Just beyond the headlines, its influence is growing.
# Bloomberg
# 2018-06-16 08:00:00
# China's Huawei rebuts Australian security concerns amid Sino-Canberra tensions
# https://news.google.com/articles/CAIiEPF7YDU59wSKeA45BjXCeLAqGAgEKg8IACoHCAow-8ykCjDv13cw7IHqAQ
# Chinese telecoms equipment maker Huawei Technologies refuted Australian claims it poses a security risk, calling the criticism "ill-informed" in an open letter on ...
# Reuters India
# 2018-06-18 14:04:54
# Travelers at Taoyuan International Airport in Taoyuan City, northern Taiwan. China has put pressure on airlines flying to China as well as to the International Air Transport Association (IATA) to order airlines to change Taiwan destinations as part of China.
# https://news.google.com/articles/CAIiECJW2FeYeIxYAkYDNkLmMJIqFggEKg4IACoGCAowjKxcMOvhCzC5zg8
# Major U.S. airlines are ignoring China's demand that they refer to Taiwan as part of China. Delta Air Lines and United Airlines both show route maps that refer to ...
# Los Angeles Times
# 2018-06-16 10:00:00
# Doug Mills/The New York Times
# https://news.google.com/articles/CAIiENLnGfVEZ3xTsaMAOTbqtHUqFwgEKg8IACoHCAowjuuKAzCWrzww9oAY
# The president approved tariffs on $50 billion worth of Chinese goods. The question is, will he use them?
# The New York Times
# 2018-06-15 06:01:57
# Talk of new tariffs extends flight to haven currencies, sparking yen and dollar rally
# https://news.google.com/articles/CAIiEA2G6mGV5M_R0KRhe08Y9dMqGAgEKg8IACoHCAowjujJATDXzBUwiJS0AQ
# Japan's yen and the U.S. dollar strengthen against their major rivals on Tuesday, as the escalating trade conflict between the world's two biggest economies sent ...
# MarketWatch
# 2018-06-19 15:16:00
# China fights Taiwan on airline websites - Banyan
# https://news.google.com/articles/CBMiUWh0dHBzOi8vd3d3LmVjb25vbWlzdC5jb20vYXNpYS8yMDE4LzA2LzE0L2NoaW5hLWZpZ2h0cy10YWl3YW4tb24tYWlybGluZS13ZWJzaXRlc9IBAA
# GIVEN all the hoopla of President Donald Trump's summit with Kim Jong Un, North Korea's dictator, the opening on the same day of a new American ...
# The Economist
# 2018-06-14 11:09:00
# Lies, China And Putin: Solving The Mystery Of Wilbur Ross' Missing Fortune
# https://news.google.com/articles/CAIiEDmAoZxynM4mZYZNbJ87xXkqFQgEKg0IACoGCAowrqkBMKBFMI_CEg
# In November 2017, Wilbur Ross confirmed in writing to the federal Office of Government Ethics that he had divested everything he promised. But that was not ...
# Forbes Now
# 2018-06-18 05:00:00
# White House announces 25 percent tariff on Chinese tech goods
# https://news.google.com/articles/CAIiECKc3WBfRL7WwKsZOBFcl54qFggEKg4IACoGCAow3O8nMMqOBjD38Ak
# Today, President Trump announced an aggressive new set of tariffs against China, setting a 25 percent import tax on $50 billion worth of “industrially significant ...
# The Verge
# 2018-06-15 11:14:57
# Magna announces partnership to build electric vehicles in China
# https://news.google....
# The Ontario-based auto parts giant is joining forces with Beijing Electric Vehicle, with the first cars set to roll off assembly line in 2020.
# The Globe and Mail
# 2018-06-18 18:21:37
# South Pacific Nation Shrugs Off Worries on China’s Influence
# https://news.google.com/articles/CAIiEBbHvp2gW6YLWbPIakS-dGYqFwgEKg8IACoHCAowjuuKAzCWrzww5oEY
# To calm security concerns about China's growing influence in the South Pacific, Vanuatu's foreign minister shared a contract his country signed with China in ...
# The New York Times
# 2018-06-13 02:22:06
# Flags emblazoned with the Trump name flying alongside Emirati flags and banners showing the logo of property developer Damac at the Trump International Golf Course, an earlier Dubai development, in 2017.
# https://news.google.com/articles/CAIiEIGnlO5Pi8YuN-O_pjphMggqFwgEKg8IACoHCAowjuuKAzCWrzwwt4QY
# A new Trump-affiliated real-estate project in Dubai will feature an 18-hole golf course designed by Tiger Woods, extensive greenery and hundreds of luxury ...
# The New York Times
# 2018-06-15 10:21:33
# Escalating U.S.-China trade spat comes at a bad time for global growth, economist says
# https://news.google.com/articles/CAIiEENBDEBjmwzboF_Tl0iOljgqGAgEKg8IACoHCAowjujJATDXzBUw2JS0AQ
# China was already unlikely to ride to the rescue of global growth. The trade spat between Washington and Beijing will dampen growth and sentiment globally, ...
# MarketWatch
# 2018-06-19 14:11:00
# Ivanka Trump at the White House last week.
# https://news.google.com/articles/CAIiEAAUsPQyJl_AovdQGvaqMqEqFwgEKg8IACoHCAowjuuKAzCWrzww5oEY
# The first daughter was mocked after it emerged that a phrase she described as Chinese might have originated in the United States.
# The New York Times
# 2018-06-12 03:47:07
# China wants to track citizens’ cars with mandatory RFID chips
# https://news.google.com/articles/CAIiEGng7q7TTtXwouWUrpOT5DIqFwgEKg4IACoGCAow3O8nMMqOBjCkztQD
# The Chinese government is readying a program that will make it possible to track citizens' cars using RFID chips, according to The Wall Street Journal.
# The Verge
# 2018-06-13 15:24:16
# Malaysia gives a big jolt to China's One Belt, One Road projects
# https://news.google.com/articles/CAIiEAL-Kh8Oek4CNBu3SQt8wOgqFwgEKg8IACoHCAow34KMAjCz9Swwr7NB
# The new Malaysian regime may not be as favourable towards the Chinese president XI Jinping's pet project, OBOR, as the earlier one headed by Najib Razak.
# The Economic Times
# 2018-06-17 14:22:19
# Following reports of a deal, Qualcomm-NXP are said to still be waiting for a China nod: Sources
# https://news.google.
# China has yet to approve U.S. chipmaker Qualcomm's proposed $44 billion acquisition of NXP Semiconductors, sources said.
# CNBC
# 2018-06-14 18:57:00
# Rand skids as US, China trade war flares
# https://news.google.com/articles/CBMiWWh0dHBzOi8vd3d3LmZpbjI0LmNvbS9NYXJrZXRzL0N1cnJlbmNpZXMvcmFuZC1za2lkcy1hcy11cy1jaGluYS10cmFkZS13YXItZmxhcmVzLTIwMTgwNjE40gEA
# The rand continued to trade at six-month lows on Monday, skidding more than 1.7% to the US dollar as global developments continued to weigh on the local ...
# Fin24
# 2018-06-18 11:12:00
# How Chinese tech giants like Alibaba are bringing AI to neighborhood corner stores
# https://news.google.com/articles/CAIiEGalns4cLcHKdwkkkLM1GbsqGQgEKhAIACoHCAowysWECzCkqIEDMKCkgwY
# The future of retail is playing out in China's mom-and-pop shops.
# Axios
# 2018-06-17 13:56:39
# China Is Rolling Out A Mandatory Program That Puts Tracking Chips In Every Car
# https://news.google.com/articles/CBMiN2h0dHBzOi8vZnV0dXJpc20uY29tL2NoaW5hLW1hbmRhdG9yeS1yZmlkLWNhci10cmFja2luZy_SAXZodHRwczovL2Z1dHVyaXNtLWNvbS5jZG4uYW1wcHJvamVjdC5vcmcvdi9zL2Z1dHVyaXNtLmNvbS9jaGluYS1tYW5kYXRvcnktcmZpZC1jYXItdHJhY2tpbmcvYW1wLz9hbXBfanNfdj0wLjEjd2Vidmlldz0x
# The Chinese government wants to track every single car with the use of an RFID tag. And they're guaranteed to get away with it, too.
# Futurism
# 2018-06-14 15:58:50
# play_arrow
# https://news.google.com/articles/CAIiEFELAUI1K-GB6uEkTniLmyQqGQgEKhAIACoHCAowief2CjCJ2dUCMNvwrAU
# China has been accused of using its dominance of the world's supply of squid to provide low-quality seafood to other countries and intimidate their ships in ...
# South China Morning Post
# 2018-06-17 08:30:00
# China plans historic mission to the moon's 'dark' side
# https://news.google._YW1wX2pzX3Y9MC4xI3dlYnZpZXc9MQ
# China's Chang'e-4 lunar probe is scheduled to launch in December toward the moon's far side, a place no nation has ever visited.
# NBCNews.com
# 2018-06-15 14:41:00
# China, Paul Manafort, Immigration: Your Friday Evening Briefing
# https://news.google.
# (Want to get this briefing by email? Here's the sign-up.) Good evening. Here's the latest. Image. CreditRoss Mantle for The New York Times. 1. The Trump ...
# New York Times
# 2018-06-15 18:08:04
# play_arrow
# https://news.google.com/articles/CAIiEDF-JYjfi-4AS6039M44sHAqGQgEKhAIACoHCAowocv1CjCSptoCMPrTpgU
# On January 1, China banned all trade in ivory, a move aimed at stopping the killing of elephants by cutting demand for the material in the world's largest market.
# CNN
# 2018-06-19 04:48:33
# Is China's growth model a threat to free-market economics?
# https://news.google.com/articles/CBMiaWh0dHBzOi8vd3d3LmVjb25vbWlzdC5jb20vb3Blbi1mdXR1cmUvMjAxOC8wNi8xMy9pcy1jaGluYXMtZ3Jvd3RoLW1vZGVsLWEtdGhyZWF0LXRvLWZyZWUtbWFya2V0LWVjb25vbWljc9IBAA
# This is a guest contribution to our debate: Should the West worry about the threat to liberal values posed by China's rise? China has delivered some of the most ...
# The Economist
# 2018-06-13 10:34:00
# Jialun Deng
# https://news.google.com/articles/CAIiEAdnPLSpAaotcqnv5G-vAl8qFwgEKg8IACoHCAowjuuKAzCWrzwwt4QY
# The tech giant's experience made many people in China see how far the country still has to go. “We realized that China's prosperity was built on sand.”
# The New York Times
# 2018-06-10 18:41:25
# Kudlow Says Don't Blame Trump as China Warns of Trade Pullback
# https://news.google.com/articles/CAIiEIxMWCKBsij_YavB-yhqLtIqGQgEKhAIACoHCAow4uzwCjCF3bsCMIrOrwM
# Blame China and those who are breaking trade rules, not Donald Trump, White House economic adviser Larry Kudlow said as China warned that all ...
# Bloomberg
# 2018-06-03 00:27:31
# Does China’s new South Pacific mega-wharf pose a risk to Australia?
# https://news.google.
# Experts have warned China's latest development project in Vanuatu - just 1500 nautical miles from Sydney - could leave Australia's east coast open to a military ...
# 9news.com.au
# 2018-06-17 08:43:00
# China’s Master Plan: A Worldwide Web of Institutions
# https://news.google._YW1wX2pzX3Y9MC4xI3dlYnZpZXc9MQ
# (This is the third part of a series on China's effort to supplant the U.S. as the world's pre-eminent geopolitical power. Read the first two parts here: A Global ...
# Bloomberg
# 2018-06-12 07:00:00
# Zhang Hongchao, an engineering professor at Tongji University in Shanghai, helped develop Pavenergy’s solar road surface.
# https://news.google.com/articles/CAIiEKCTbI7qbZp-6i2IMGhHSOMqFwgEKg8IACoHCAowjuuKAzCWrzwwqIQY
# Western countries have been looking into putting solar panels on roads for years. The Chinese have done it, installing panels on a downhill section of a ...
# The New York Times
# 2018-06-11 14:41:42
# China’s Master Plan: How the West Can Fight Back
# https://news.google._YW1wX2pzX3Y9MC4xI3dlYnZpZXc9MQ
# (This is the fourth and final column in a series on China's efforts to supplant the U.S. as the world's pre-eminent geopolitical power. Read the other parts here: A ...
# Bloomberg
# 2018-06-13 07:28:00
# A statue of Albert Gallatin, a long-serving U.S. secretary of the Treasury, stands in front of the U.S. Treasury building in Washington, D.C., U.S., on Tuesday, Aug. 16, 2011. U.S. President Barack Obama went on the attack against Republicans running to oppose him next year and those in Congress, whose refusal to compromise, he said, was to blame for the economic uncertainty gripping consumers and businesses. Photographer: Brendan Smialowski
# https://news.google.com/articles/CAIiEDNiB46iawNv7NPgSb6DdGkqGQgEKhAIACoHCAow4uzwCjCF3bsCMIrOrwM
# China remained the largest foreign owner of Treasuries in April even with a slight drop in holdings, as the Asian nation's appetite for U.S. government debt ...
# Bloomberg
# 2018-06-15 16:00:00
# Scott Olson/Getty Images
# https://news.google.com/articles/CAIiEF9Jtb8gUbxI-GazUPjdfsIqFwgEKg8IACoHCAow1tzJATDnyxUw54IY
# Beijing retaliated against planned U.S. tariffs on Chinese goods by targeting high-value American exports—including farm products, cars, and crude ...
# The Wall Street Journal
# 2018-06-15 18:34:00
# Valve will officially launch Steam in China
# https://news.google.com/articles/CAIiEHvtDdWxrjW_2rwRsdXxrXIqFggEKg4IACoGCAow3O8nMMqOBjD38Ak
# Valve plans to bring Steam to China in an official capacity, expanding the reach of its distribution *service* and games library to a huge additional audience.
# The Verge
# 2018-06-11 19:34:44
# China's clean skies battle expands, clouding economic outlook
# https://news.google.
# XUZHOU, China (Reuters) - The frontlines of China's war on pollution are moving beyond smog-prone Beijing and surrounding cities, driven by an effort to ...
# Reuters
# 2018-06-14 02:03:00
# SINGAPORE - JUNE 11: (CHINA OUT, SOUTH KOREA OUT) U.S. Secretary of State Mike Pompeo speaks during a press briefing ahead of the U.S.-North Korea summit on June 11, 2018 in Singapore. (Photo by The Asahi Shimbun via Getty Images)
# https://news.google.com/articles/CAIiEHaBGKjQjqO6fwgjAPId1zAqGQgEKhAIACoHCAowyNj6CjDyiPICMKb_xAU
# Secretary of State Mike Pompeo and his counterpart Foreign Minister Wang Yi reaffirmed their work toward bettering the U.S.-China relationship amid ongoing ...
# CBS News
# 2018-06-14 07:04:00
# Global pharma bleeds talent to China start-ups
# https://news.google.com/articles/CAIiEFtPjZaApPFwDBcBrfumxrgqFwgEKg8IACoHCAow-4fWBzD4z0gw0tp6
# Multinational drug companies in China are fighting to hold on to top talent as senior local staff leave to join a booming domestic biotechnology sector drawing ...
# Financial Times
# 2018-06-16 23:54:32
# China is winning the global tech race
# https://news.google.com/articles/CAIiEBlJ63NBMcKBFXMxYp7E7tgqFwgEKg8IACoHCAow-4fWBzD4z0gwgtt6
# Admirers say Chinese technology investments are akin to the Belt and Road Initiative.
# Financial Times
# 2018-06-17 08:20:53
# China's industrial output in May was weaker than expected
# https://news.google._YW1wX2pzX3Y9MC4xI3dlYnZpZXc9MQ
# China's industrial output grew 6.8 percent in May from a year earlier, missing expectations, while fixed-asset investment growth slowed to 6.1 percent in the first ...
# CNBC
# 2018-06-13 22:10:00
# China suggests sanctions relief for North Korea after Trump-Kim summit
# https://news.google.
# China suggested on Tuesday that sanctions relief could be considered for North Korea, after U.S. President Donald Trump and North Korean leader Kim Jong ...
# CNBC
# 2018-06-12 04:52:00
# play_arrow
# https://news.google.com/articles/CAIiEPtBJux-DuJuT0zySF5bahMqGQgEKhAIACoHCAowocv1CjCSptoCMPrWrwU
# Gary Hartman voted for Trump and thought tariffs would save the factory he runs in Berwick, Pennsylvania. Now he's not so sure they're coming.
# CNN
# 2018-06-14 13:57:59
# Brace for an even bigger bubble in China’s stock markets
# https://news.google.com/articles/CAIiEO8PLtKNEkCqv72AF3B6BxEqGQgEKhAIACoHCAow_Jf7CjDCtfMCMMPdyQU
# Rocky ride ahead if a new financial instrument fashioned after American Depositary Receipts that lets Chinese investors dabble in the country's tech champions ...
# This Week In Asia
# 2018-06-17 20:17:39
# China's Didi steps up challenge to Uber with plan to launch in Australia
# https://news.google.com/articles/CAIiEBivGl_RorU-f6n8HeigvL0qGQgEKhAIACoHCAow2Nb3CjDivdcCMMPf7gU
# Chinese ride-hailing giant Didi Chuxing is headed for Australia this month. The company said Friday that it plans to launch its ride-hailing *service* Didi Express in ...
# CNBC
# 2018-06-15 05:57:00

# %% [markdown]
# ### Now we put everything together
# Put the data into a df, save it as a CSV, then send as attachment using mailgun.

# %%
# Generating auto-emails on China-related news from Google News

from bs4 import BeautifulSoup
import requests
import datetime
import re
import pandas as pd

response = requests.get("https://news.google.com/search?q=China&hl=en-US&gl=US&ceid=US%3Aen").content
soup = BeautifulSoup(response, "html.parser")

briefing = []

featured = soup.find(class_='lBwEZb BL5WZb xP6mwf').findAll('div',attrs={'jscontroller':'d0DtYd'})
for feature in featured:
    feature_row = {}
    feature_article = feature.find('article').find(class_='ZulkBc qNiaOd')
    feature_row['title'] = feature_article.span.text
    feature_row['url'] = 'https://news.google.com'+feature_article.a['href'][1:]
    feature_row['first_lines'] = feature_article.find(class_='HO8did Baotjf').text
    feature_row['source'] = feature.find(class_='QmrVtf kybdz').find('div',attrs={'class':'PNwZO zhsNkd'}).text
    feature_rawtime = feature.find('time')['datetime'].split(': ')[1]
    feature_row['time'] = datetime.datetime.fromtimestamp(int(feature_rawtime)).strftime('%Y-%m-%d %H:%M:%S')
    briefing.append(feature_row)

articles = soup.find(class_='lBwEZb BL5WZb xP6mwf').findAll('div',attrs={'jsmodel':'zT6vwb'})
for article in articles:
    article_row = {}
    article_row['title'] = article.find('span').text
    article_row['url'] = 'https://news.google.com'+article.find('a',attrs={'class':'ipQwMb Q7tWef'})['href'][1:]
    article_row['first_lines'] = article.find('p').text
    article_row['source'] = article.find(class_='KbnJ8').text
    article_rawtime = re.findall(r'[\d]+', article.find('time')['datetime'].split(': ')[1])[0]
    article_row['time'] = datetime.datetime.fromtimestamp(int(article_rawtime)).strftime('%Y-%m-%d %H:%M:%S')
    briefing.append(article_row)
    
df = pd.DataFrame(briefing)
right_now = datetime.datetime.now()
date_string_filename = right_now.strftime("%Y-%b-%d_%-I%p")
df.to_csv('China_news_briefing_{}.csv'.format(date_string_filename), index=False)
date_string_mail = right_now.strftime("%-I %p")

requests.post(
        "https://api.mailgun.net/v3/MY_SANDBOX_DOMAIN/messages",
        auth=("api", "MY_API_KEY"),
        files=[("attachment", open('China_news_briefing_{}.csv'.format(date_string_filename)))],
        data={"from": "Edward Hong <mailgun@MY_SANDBOX_DOMAIN>",
              "to": ["Edward.YSHF@gmail.com"],
              "subject": "{} China News Briefing".format(date_string_mail),
              "text": "See attachment to learn what's new about China."})
# Out:
# <Response [200]>
